# %%
import pandas as pd
import streamlit as st
import numpy as np

# %%
data = pd.read_csv('https://privacyrights.org/sites/default/files/2020-01/PRC%20Data%20Breach%20Chronology%20-%201.13.20.csv',usecols=['Date Made Public', 'Company', 'City', 'State', 'Type of breach',
       'Type of organization', 'Total Records', 'Description of incident',
       'Year of Breach', 'Latitude',
       'Longitude'])

# %%
# data.head()

Year = data['Year of Breach'].tolist()
Date = data['Date Made Public'].tolist()

Difference=0
for i in range(len(data)):
    Temp = Date[i].split('/')
    if int(Temp[2].strip())==Year[i]:
        continue
    else:
        Difference+=1

# print(Difference/len(data))

# There are differences between Data Made Public and Data of Breach; 3.73% of instances.

data['Date Made Public']=pd.to_datetime(data['Date Made Public'])
data['Total Records']=data['Total Records'].str.replace(',','').fillna('0')
data['Total Records']=data['Total Records'].astype('int64')
data.dtypes
# Out:
# Date Made Public           datetime64[ns]
# Company                            object
# City                               object
# State                              object
# Type of breach                     object
# Type of organization               object
# Total Records                       int64
# Description of incident            object
# Year of Breach                      int64
# Latitude                          float64
# Longitude                         float64
# dtype: object

# %%
# data.head()

City = data['City'].to_list()
State = data['State'].to_list()
Longitude = data['Longitude'].to_list()
Latitude = data['Latitude'].to_list()

badrows=[]
for i in range(len(data)):
    if pd.isna(City[i]) and pd.isna(State[i]):
        if pd.isna(Longitude[i]) and pd.isna(Latitude[i]):
            badrows.append(i)
        else:
            continue
    else:
        continue

# print(len(badrows))
# print(badrows)

# %%
# BSF
# Businesses (Financial and Insurance Services)
data = data.replace('BSF','Financial/Insurance Business')

# BSO
# Businesses (Other)
data = data.replace('BSO','Other Business')

# BSR
# Businesses (Retail/Merchant including Online Retail)
data = data.replace('BSR','Retail Business')

# EDU
# Educational Institutions
data = data.replace('EDU','Educational Institution')

# GOV
# Government & Military
data = data.replace('GOV','Government/Military')

# MED
# Healthcare, Medical Providers and Medical Insurance Services
data = data.replace('MED','Healthcare/Medical Services')

# NGO
# Nonprofits
data = data.replace('NGO','Nonprofit')

# UNKN
# Unknown
data = data.replace('UNKN','Unknown')

data.head()
# Out:
#   Date Made Public                                            Company  \
# 0       2006-03-03                                      PayDay OK LLC
# 1       2012-01-04  SF Fire Credit Union, Pacifica-Coastside Credi...
# 2       2012-02-18                 BDO USA, Rubio's Restaurants, Inc.
# 3       2012-02-22                         DHI Mortgage Company, Ltd.
# 4       2012-03-12                          Impairment Resources, LLC
#
#             City       State Type of breach          Type of organization  \
# 0            NaN  New Jersey           HACK  Financial/Insurance Business
# 1  San Francisco  California           PORT  Financial/Insurance Business
# 2      San Diego  California           PORT               Retail Business
# 3         Austin       Texas           HACK  Financial/Insurance Business
# 4      San Diego  California           PORT   Healthcare/Medical Services
#
#    Total Records                            Description of incident  \
# 0             88  The company's website was breached sometime ar...
# 1              0  The December 29, 2011 theft of a laptop from a...
# 2              0  BDO was contracted by Rubio's to perform finan...
# 3              0  On February 10, 2012, DHI Mortgage became awar...
# 4          14000  An office burglary on New Year's Eve 2011 resu...
#
#    Year of Breach   Latitude   Longitude
# 0            2006  40.058324  -74.405661
# 1            2012  37.774930 -122.419416
# 2            2012  32.715329 -117.157255
# 3            2012  30.267153  -97.743061
# 4            2012  32.715329 -117.157255

# %%
data.to_csv('PRC_Clean.csv')
